# %% [markdown]
# <a href="https://colab.research.google.com/github/desaiankitb/stable-diffusion-colab/blob/main/damo_vilab_text_to_video_ms_1_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.1/989.1 kB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 94.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.8 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.20.2-py3-none-any.whl size=1342633 sha256=e2505bad842d7542fd8a5647b811cd644a47b451598bbff70c78485dc8f7a05b
#   Stored in directory: /root/.cache/pip/wheels/dc/8b/d9/34f7a1936109e05e9bba0cc2241a6f8cd89e25959dc7aae942
# Successfully built diffusers
# ...

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "astronaut in the ocean"
video_frames = pipe(prompt, num_inference_steps=100).frames
video_path = export_to_video(video_frames)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print(video_path)
# Out:
# /tmp/tmpnca2sigd.mp4

# %%
prompt = "astronaut in the ocean"
video_frames = pipe(prompt, num_inference_steps=100).frames
video_path = export_to_video(video_frames)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print(video_path)
# Out:
# /tmp/tmppr69nni4.mp4

# %%
prompt = "chair over a cloud"
video_frames = pipe(prompt, num_inference_steps=25).frames
video_path = export_to_video(video_frames)
print(video_path)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# /tmp/tmpwdr76bjo.mp4
